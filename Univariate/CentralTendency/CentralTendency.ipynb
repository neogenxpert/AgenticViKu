# %%
import pandas as pd

# %%
ds = pd.read_csv("Placement.csv")

# %%
#ds.info()

# %%
from Univariate import Univariate
Qual,Quan = Univariate.QualQuan(ds)

# %%
'''
qual , quan = [] , []
# Regular Method
for items in ds.columns:
    if ds[items].dtype == 'O':
        qual.append(items)
    else:
        quan.append(items)
# Optimized method
for items in ds.columns :
    (qual if ds[items].dtype == 'O' else quan).append(items)
# Function creation

def QualQuan(dataset) :
    for items in ds.columns :
        (qual if ds[items].dtype == 'O' else quan).append(items)
    return qual, quan

qual,quan = QualQuan(ds)
'''
# Out:
# "\nqual , quan = [] , []\n# Regular Method\nfor items in ds.columns:\n    if ds[items].dtype == 'O':\n        qual.append(items)\n    else:\n        quan.append(items)\n# Optimized method\nfor items in ds.columns :\n    (qual if ds[items].dtype == 'O' else quan).append(items)\n# Function creation\n\ndef QualQuan(dataset) :\n    for items in ds.columns :\n        (qual if ds[items].dtype == 'O' else quan).append(items)\n    return qual, quan\n\nqual,quan = QualQuan(ds)\n"

# %%
Qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %% [markdown]
# # Central Tendency

# %%
ds["ssc_p"].mean() # Average Value
# Out:
# np.float64(67.30339534883721)

# %%
ds["ssc_p"].median() # Center Value
# Out:
# np.float64(67.0)

# %%
ds["ssc_p"].mode() # Repeated value
# Out:
# 0    62.0
# Name: ssc_p, dtype: float64

# %%
ds["ssc_p"].mode() [0]# Repeated value
# Out:
# np.float64(62.0)

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=Quan)

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive.loc["ssc_p","Mode"]=0

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=Quan)
for columnName in Quan:
    descriptive.loc["Mean",columnName]=ds[columnName].mean()
    descriptive.loc["Median",columnName]=ds[columnName].median()
    descriptive.loc["Mode",columnName]=ds[columnName].mode()[0]

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode        1       62.0       63.0       65.0       60.0       56.7
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode         300000.0

# %% [markdown]
# # Average mark of ssc ,hsc , degree is between 66-67.5, mba is 62 but in entrence they have scored 72
# # Outlier of close to 23k present in Mean Salary value, identified through median
# # Repeated value of SSC is 62 and similarly for other features. repeated Salary for this set of people is 3lk.

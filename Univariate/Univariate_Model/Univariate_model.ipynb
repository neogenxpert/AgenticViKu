# %%
import pandas as pd

# %%
ds = pd.read_csv("Placement.csv")

# %%
#ds.info()

# %%
from Univariate import Univariate
Qual,Quan = Univariate.QualQuan(ds)

# %%
Qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %% [markdown]
# # Central Tendency

# %%
ds.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
ds["ssc_p"].mean() # Average Value
# Out:
# np.float64(67.30339534883721)

# %%
ds["ssc_p"].median() # Center Value
# Out:
# np.float64(67.0)

# %%
ds["ssc_p"].mode() # Repeated value
# Out:
# 0    62.0
# Name: ssc_p, dtype: float64

# %%
ds["ssc_p"].mode() [0]# Repeated value
# Out:
# np.float64(62.0)

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=Quan)

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive.loc["ssc_p","Mode"]=0

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=Quan)
for columnName in Quan:
    descriptive.loc["Mean",columnName]=ds[columnName].mean()
    descriptive.loc["Median",columnName]=ds[columnName].median()
    descriptive.loc["Mode",columnName]=ds[columnName].mode()[0]

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode        1       62.0       63.0       65.0       60.0       56.7
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode         300000.0

# %% [markdown]
# # Percentile

# %%
import numpy as np

# %%
np.percentile(ds["ssc_p"],25)
# Out:
# np.float64(60.599999999999994)

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100","IQR","1.5 Rule","Lesser Quartile","Greater Quartile","Min Value","Max Value"],columns=Quan)
for columnName in Quan:
    descriptive.loc["Mean",columnName]=ds[columnName].mean()
    descriptive.loc["Median",columnName]=ds[columnName].median()
    descriptive.loc["Mode",columnName]=ds[columnName].mode()[0]
    descriptive.loc["Q1:25%",columnName]=ds.describe()[columnName]["25%"]
    descriptive.loc["Q2:50%",columnName]=ds.describe()[columnName]["50%"]
    descriptive.loc["Q3:75%",columnName]=ds.describe()[columnName]["75%"]
    descriptive.loc["99%",columnName]=np.percentile(ds[columnName],99)
    descriptive.loc["Q4:100",columnName]=ds.describe()[columnName]["max"]
    descriptive.loc["IQR",columnName]=descriptive.loc["Q3:75%",columnName] - descriptive.loc["Q1:25%",columnName]
    descriptive.loc["1.5 Rule",columnName]= 1.5 * descriptive.loc["IQR",columnName]
    descriptive.loc["Lesser Quartile",columnName]= ds.describe()[columnName]["25%"] - descriptive.loc["1.5 Rule",columnName]
    descriptive.loc["Greater Quartile",columnName]=descriptive.loc["Q3:75%",columnName] + descriptive.loc["1.5 Rule",columnName]
    descriptive.loc["Min Value",columnName]=ds[columnName].min()
    descriptive.loc["Max Value",columnName]=ds[columnName].max()

# %%
descriptive
# Out:
#                    sl_no      ssc_p      hsc_p   degree_p    etest_p  \
# Mean               108.0  67.303395  66.333163  66.370186  72.100558
# Median             108.0       67.0       65.0       66.0       71.0
# Mode                   1       62.0       63.0       65.0       60.0
# Q1:25%              54.5       60.6       60.9       61.0       60.0
# Q2:50%             108.0       67.0       65.0       66.0       71.0
# Q3:75%             161.5       75.7       73.0       72.0       83.5
# 99%               212.86       87.0      91.86      83.86       97.0
# Q4:100             215.0       89.4       97.7       91.0       98.0
# IQR                107.0       15.1       12.1       11.0       23.5
# 1.5 Rule           160.5      22.65      18.15       16.5      35.25
# Lesser Quartile   -106.0      37.95      42.75       44.5      24.75
# Greater Quartile   322.0      98.35      91.15       88.5     118.75
# Min Value              1      40.89       37.0       50.0       50.0
# Max Value            215       89.4       97.7       91.0       98.0
#
#                       mba_p         salary
# Mean              62.278186  288655.405405
# Median                 62.0       265000.0
# Mode                   56.7       300000.0
# Q1:25%               57.945       240000.0
# Q2:50%                 62.0       265000.0
# Q3:75%               66.255       300000.0
# 99%                 76.1142            NaN
# Q4:100                77.89       940000.0
# IQR                    8.31        60000.0
# 1.5 Rule             12.465        90000.0
# Lesser Quartile       45.48       150000.0
# Greater Quartile      78.72       390000.0
# Min Value             51.21       200000.0
# Max Value             77.89       940000.0

# %% [markdown]
# # Univariate Function

# %%
def Univariate(Quan,ds):
    descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100","IQR","1.5 Rule","Lesser Quartile","Greater Quartile","Min Value","Max Value"],columns=Quan)
    for columnName in Quan:
        descriptive.loc["Mean",columnName]=ds[columnName].mean()
        descriptive.loc["Median",columnName]=ds[columnName].median()
        descriptive.loc["Mode",columnName]=ds[columnName].mode()[0]
        descriptive.loc["Q1:25%",columnName]=ds.describe()[columnName]["25%"]
        descriptive.loc["Q2:50%",columnName]=ds.describe()[columnName]["50%"]
        descriptive.loc["Q3:75%",columnName]=ds.describe()[columnName]["75%"]
        descriptive.loc["99%",columnName]=np.percentile(ds[columnName],99)
        descriptive.loc["Q4:100",columnName]=ds.describe()[columnName]["max"]
        descriptive.loc["IQR",columnName]=descriptive.loc["Q3:75%",columnName] - descriptive.loc["Q1:25%",columnName]
        descriptive.loc["1.5 Rule",columnName]= 1.5 * descriptive.loc["IQR",columnName]
        descriptive.loc["Lesser Quartile",columnName]= ds.describe()[columnName]["25%"] - descriptive.loc["1.5 Rule",columnName]
        descriptive.loc["Greater Quartile",columnName]=descriptive.loc["Q3:75%",columnName] + descriptive.loc["1.5 Rule",columnName]
        descriptive.loc["Min Value",columnName]=ds[columnName].min()
        descriptive.loc["Max Value",columnName]=ds[columnName].max()
    return descriptive

# %%
Univariate(Quan,ds)
# Out:
#                    sl_no      ssc_p      hsc_p   degree_p    etest_p  \
# Mean               108.0  67.303395  66.333163  66.370186  72.100558
# Median             108.0       67.0       65.0       66.0       71.0
# Mode                   1       62.0       63.0       65.0       60.0
# Q1:25%              54.5       60.6       60.9       61.0       60.0
# Q2:50%             108.0       67.0       65.0       66.0       71.0
# Q3:75%             161.5       75.7       73.0       72.0       83.5
# 99%               212.86       87.0      91.86      83.86       97.0
# Q4:100             215.0       89.4       97.7       91.0       98.0
# IQR                107.0       15.1       12.1       11.0       23.5
# 1.5 Rule           160.5      22.65      18.15       16.5      35.25
# Lesser Quartile   -106.0      37.95      42.75       44.5      24.75
# Greater Quartile   322.0      98.35      91.15       88.5     118.75
# Min Value              1      40.89       37.0       50.0       50.0
# Max Value            215       89.4       97.7       91.0       98.0
#
#                       mba_p         salary
# Mean              62.278186  288655.405405
# Median                 62.0       265000.0
# Mode                   56.7       300000.0
# Q1:25%               57.945       240000.0
# Q2:50%                 62.0       265000.0
# Q3:75%               66.255       300000.0
# 99%                 76.1142            NaN
# Q4:100                77.89       940000.0
# IQR                    8.31        60000.0
# 1.5 Rule             12.465        90000.0
# Lesser Quartile       45.48       150000.0
# Greater Quartile      78.72       390000.0
# Min Value             51.21       200000.0
# Max Value             77.89       940000.0

# %% [markdown]
# # Identify the outliers

# %%
lesser,greater = [], []

# %%
for columnName in Quan:
    if (descriptive.loc["Lesser Quartile",columnName] > descriptive.loc["Min Value",columnName]):
        lesser.append(columnName)
    if (descriptive.loc["Greater Quartile",columnName] < descriptive.loc["Max Value",columnName]):
        greater.append(columnName)

# %%
lesser
# Out:
# ['hsc_p']

# %%
greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %% [markdown]
# # Outlier Function

# %%
def outlier(Quan,Univariate):
    lesser,greater = [], []
    for columnName in Quan:
        if (descriptive.loc["Lesser Quartile",columnName] > descriptive.loc["Min Value",columnName]):
            lesser.append(columnName)
        if (descriptive.loc["Greater Quartile",columnName] < descriptive.loc["Max Value",columnName]):
            greater.append(columnName)
    return lesser, greater

# %%
lesser,greater = outlier(Quan,Univariate)
print("Lesser:", lesser)
print("Greater:", greater)
# Out:
# Lesser: ['hsc_p']
# Greater: ['hsc_p', 'degree_p', 'salary']

# %% [markdown]
# # Replace the Outlier

# %%
for column in lesser:
    ds.loc[ds[column]<descriptive.loc["Lesser Quartile",column], column]=descriptive.loc["Lesser Quartile",column]
for column in greater:
     ds.loc[ds[column]>descriptive.loc["Greater Quartile",column], column]=descriptive.loc["Greater Quartile",column]

# %% [markdown]
# # ReplaceOutlier Function

# %%
def replace_outlier(ds,outlier):
    for column in lesser:
        ds.loc[ds[column]<descriptive.loc["Lesser Quartile",column],column]=descriptive.loc["Lesser Quartile",column]
    for column in greater:
        ds.loc[ds[column]>descriptive.loc["Greater Quartile",column],column]=descriptive.loc["Greater Quartile",column]  
    return lesser , greater

# %%
replace_outlier(ds,outlier)
# Out:
# (['hsc_p'], ['hsc_p', 'degree_p', 'salary'])

# %%
lesser,greater = [], []

# %%
for columnName in Quan:
    if (descriptive.loc["Lesser Quartile",columnName] > ds[columnName].min()):
        lesser.append(columnName)
    if (descriptive.loc["Greater Quartile",columnName] < ds[columnName].max()):
        greater.append(columnName)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %% [markdown]
# # Frequency Calculation

# %%
ds["ssc_p"].value_counts()    #.index,.values,soet_index,sort_values
# Out:
# ssc_p
# 62.00    11
# 63.00    10
# 67.00     9
# 73.00     9
# 52.00     9
#          ..
# 55.68     1
# 41.00     1
# 83.33     1
# 43.00     1
# 80.60     1
# Name: count, Length: 103, dtype: int64

# %%
freqTable = pd.DataFrame(columns=["Unique Value","Frequency","Rel_Frequency","CumSum"])

# %%
freqTable["Unique Value"] = ds["ssc_p"].value_counts().index
freqTable["Frequency"] = ds["ssc_p"].value_counts().values
freqTable["Rel_Frequency"] = (freqTable["Frequency"]/103)
freqTable["CumSum"] = freqTable["Rel_Frequency"].cumsum()

# %%
freqTable
# Out:
#      Unique Value  Frequency  Rel_Frequency    CumSum
# 0           62.00         11       0.106796  0.106796
# 1           63.00         10       0.097087  0.203883
# 2           67.00          9       0.087379  0.291262
# 3           73.00          9       0.087379  0.378641
# 4           52.00          9       0.087379  0.466019
# ..            ...        ...            ...       ...
# 98          55.68          1       0.009709  2.048544
# 99          41.00          1       0.009709  2.058252
# 100         83.33          1       0.009709  2.067961
# 101         43.00          1       0.009709  2.077670
# 102         80.60          1       0.009709  2.087379
#
# [103 rows x 4 columns]

# %% [markdown]
# # freqTable Function

# %%
def freqTable(columnName,ds):
    freqTable = pd.DataFrame(columns=["Unique Value","Frequency","Rel_Frequency","CumSum"])
    freqTable["Unique Value"] = ds[columnName].value_counts().index
    freqTable["Frequency"] = ds[columnName].value_counts().values
    freqTable["Rel_Frequency"] = (freqTable["Frequency"]/103)
    freqTable["CumSum"] = freqTable["Rel_Frequency"].cumsum()
    return freqTable

# %%
freqTable("ssc_p",ds)
# Out:
#      Unique Value  Frequency  Rel_Frequency    CumSum
# 0           62.00         11       0.106796  0.106796
# 1           63.00         10       0.097087  0.203883
# 2           67.00          9       0.087379  0.291262
# 3           73.00          9       0.087379  0.378641
# 4           52.00          9       0.087379  0.466019
# ..            ...        ...            ...       ...
# 98          55.68          1       0.009709  2.048544
# 99          41.00          1       0.009709  2.058252
# 100         83.33          1       0.009709  2.067961
# 101         43.00          1       0.009709  2.077670
# 102         80.60          1       0.009709  2.087379
#
# [103 rows x 4 columns]
